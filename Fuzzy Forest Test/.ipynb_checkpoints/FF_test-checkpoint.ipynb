# %%
library("fuzzyforest")
library("WGCNA")
library("randomForest")

# %% [markdown]
# $$y_{t} = 5X^{(1)}_{t}+2X^{(2)}_{t}+2X^{(3)}_{t}+5X^{(2)}_{t}X^{(3)}_{t}
# +5X_{t}^{(301)}+2X^{(302)}_{t}+2X^{(303)}_{t}+5X^{(302)}_{t}X^{(303)}_{t}
# +\epsilon_{t}$$ where $\epsilon_{t}$ and X matrix have different structure as described SimData (ipynb file).

# %% [markdown]
# * ${\large \textbf{Simulated data in csv file} }$
#     * data1: independent features and no time structure
#     * data2: grouped features, no time structure (like in paper of Fuzzy Forest)
#     * data3: grouped features, CS time structure only on y (rows of X are iid)
#     * data4: grouped features, AR structure on X as in pdf simulation_AR

# %% [markdown]
# # Fuzzy Forest

# %% [markdown]
# Test the performance of Fuzzy Forest (whether it selectes the correct features) on several data set with different structured on time and features.

# %% [markdown]
# ## data1

# %% [markdown]
# For the first dataset, I will do the testing precedure step by step for information

# %% [markdown]
# ### Data preparation step by step

# %%
data1 <- read.csv(file="data1.csv", header=TRUE, sep=",")
cat(ncol(data1))
data1[1:5,]
# Out:
# 402
#   X V1          V2         V3          V4         V5          V6
# 1 1  0.49884296  0.4584150 -0.38538988  0.1742270 -1.01807920 0.1839684
# 2 2 -0.01176638 -0.3259922  0.27715570 -1.3794883  0.38103368 0.1628988
# 3 3  0.27940556  0.2378416  0.05995384  0.5787147 -0.29129770 0.4409428
# 4 4  0.07305287 -0.1783826 -0.45124422 -0.3093175 -0.06152164 0.7497079
# 5 5 -0.52916867  0.4209453  0.67523736 -1.2400964 -2.88565821 0.6331321
#   V7         V8          V9          ... V392       V393        V394
# 1  0.7595764  0.24948179  0.75240718 ... -0.8579183  0.38954308 -0.8637574
# 2  0.7068795  0.84993711 -0.06282395 ... -0.2885129  0.28290784 -1.1734713
# 3 -1.2117725  1.15919005 -1.37681810 ...  0.4916707  0.01982594 -0.6549691
# 4 -1.0846595 -0.07556474  0.38912006 ... -0.1966560  0.47105531  1.0671176
# 5 -0.2548352 -0.81417783  0.32872366 ...  0.1879879 -0.14329729  0.5986962
#   V395       V396       V397       V398       V399       V400        V401
# ...

# %%
data1 = data1[,-1] # delete the X column (name of rows)
cat(dim(data1))
data1[1:5,]
# Out:
# 500 401
#   V1          V2         V3          V4         V5          V6
# 1  0.49884296  0.4584150 -0.38538988  0.1742270 -1.01807920 0.1839684
# 2 -0.01176638 -0.3259922  0.27715570 -1.3794883  0.38103368 0.1628988
# 3  0.27940556  0.2378416  0.05995384  0.5787147 -0.29129770 0.4409428
# 4  0.07305287 -0.1783826 -0.45124422 -0.3093175 -0.06152164 0.7497079
# 5 -0.52916867  0.4209453  0.67523736 -1.2400964 -2.88565821 0.6331321
#   V7         V8          V9          V10        ... V392       V393
# 1  0.7595764  0.24948179  0.75240718 -0.1491975 ... -0.8579183  0.38954308
# 2  0.7068795  0.84993711 -0.06282395  1.7281182 ... -0.2885129  0.28290784
# 3 -1.2117725  1.15919005 -1.37681810 -0.3935021 ...  0.4916707  0.01982594
# 4 -1.0846595 -0.07556474  0.38912006 -1.5254264 ... -0.1966560  0.47105531
# 5 -0.2548352 -0.81417783  0.32872366  1.1079808 ...  0.1879879 -0.14329729
#   V394       V395       V396       V397       V398       V399       V400
# ...

# %%
X = data1[,-ncol(data1)]
y = data1[,ncol(data1)]

# %% [markdown]
# ### Fitting

# %%
# params is stored in xxx_control object
# power: belta (I choose it without much care)
WGCNA_params = WGCNA_control(power=3,TOMType="unsigned",minModuleSize=30,
                            numericLabels=TRUE,pamRespectsDendro=FALSE)

mtry_factor     = 1 # mtry = sqrt(p)*mtry_factor; mtry is the num in subspace method
drop_fraction   = 0.25 # drop xxx in each iteration of RFE-RF
number_selected = 8 # we want 10 out of all features
keep_fraction   = 0.05 # keep xxx for each module
min_ntree        = 500 # used for calculating ntree
ntree_factor    = 5 # used for calculating ntree
final_ntree     = 500 # RF in selecting step

screen_params = screen_control(drop_fraction = drop_fraction,
                              keep_fraction  = keep_fraction,
                              min_ntree      = min_ntree,
                              mtry_factor    = mtry_factor,
                              ntree_factor   = ntree_factor)

select_params = select_control(drop_fraction  = drop_fraction,
                              number_selected = number_selected,
                              min_ntree       = min_ntree,
                              mtry_factor     = mtry_factor,
                              ntree_factor    = ntree_factor)

# %%
# a "fuzzy_forest" object
wff_fit = wff(X,y,WGCNA_params = WGCNA_params,
             screen_params = screen_params,
             select_params = select_params,
             final_ntree = final_ntree)
# Out:
# Warning message in blockwiseModules(datExpr = structure(list(V1 = c(0.498842959890932, :
# "blockwiseModules: mergeCloseModules failed with the following error message:
#      Error in mergeCloseModules(datExpr, colors[gsg$goodGenes], cutHeight = mergeCutHeight,  :
#   Error in moduleEigengenes(expr = exprData[[set]]$data, colors = setColors,  :
#   Color levels are empty. Possible reason: the only color is grey and grey module is excluded from the calculation.
#
#
# --> returning unmerged colors.
# "

# %% [markdown]
# ### Result

# %%
print(wff_fit)
# Out:
#   feature_name variable_importance module_membership
# 1           V1          48.2927146                 0
# 6         V301          30.9786984                 0
# 7         V302          13.1788811                 0
# 2           V2          11.4566279                 0
# 3           V3           9.6300656                 0
# 8         V303           9.0601682                 0
# 4          V25           0.6669834                 0
# 5         V230           0.5846434                 0

# %%
modplot(wff_fit)

varImpPlot(wff_fit$final_rf,type=2,main="Variable Importance Plot")
# Out:
# plot without title
# Plot with title "Variable Importance Plot"

# %% [markdown]
# Result: Perfect

# %% [markdown]
# ## Data2

# %%
#data
data2 <- read.csv(file="data2.csv", header=TRUE, sep=",")
data2 = data2[,-1] # delete the X column (name of rows)
X = data2[,-ncol(data2)]
y = data2[,ncol(data2)]

#fit
wff_fit = wff(X,y,WGCNA_params = WGCNA_params,
             screen_params = screen_params,
             select_params = select_params,
             final_ntree = final_ntree)

#results
print(wff_fit)
modplot(wff_fit)
varImpPlot(wff_fit$final_rf,type=2,main="Variable Importance Plot")
# Out:
#   feature_name variable_importance module_membership
# 1           V1           41.794964                 2
# 2           V2           40.277480                 2
# 6         V301           38.117863                 0
# 3           V3           28.376485                 2
# 5          V60           15.575058                 2
# 4          V21           14.538132                 2
# 8         V303            7.123882                 0
# 7         V302            5.599641                 0
# plot without title
# Plot with title "Variable Importance Plot"

# %% [markdown]
# ## Data3

# %%
#data
data3 <- read.csv(file="data3.csv", header=TRUE, sep=",")
data3 = data3[,-1] # delete the X column (name of rows)
X = data3[,-ncol(data3)]
y = data3[,ncol(data3)]

#fit
wff_fit = wff(X,y,WGCNA_params = WGCNA_params,
             screen_params = screen_params,
             select_params = select_params,
             final_ntree = final_ntree)

#results
print(wff_fit)
modplot(wff_fit)
varImpPlot(wff_fit$final_rf,type=2,main="Variable Importance Plot")
# Out:
#   feature_name variable_importance module_membership
# 6         V301           37.945576                 0
# 2           V2           33.016688                 2
# 3           V3           32.049616                 2
# 1           V1           30.425968                 2
# 4          V23           24.723519                 2
# 5          V25           12.772489                 2
# 8         V303            9.055669                 0
# 7         V302            7.201006                 0
# plot without title
# Plot with title "Variable Importance Plot"

# %% [markdown]
# ## Data4

# %%
#data
data4 <- read.csv(file="data4.csv", header=TRUE, sep=",")
data4 = data4[,-1] # delete the X column (name of rows)
X = data4[,-ncol(data4)]
y = data4[,ncol(data4)]

#fit
wff_fit = wff(X,y,WGCNA_params = WGCNA_params,
             screen_params = screen_params,
             select_params = select_params,
             final_ntree = final_ntree)

#results
print(wff_fit)
modplot(wff_fit)
varImpPlot(wff_fit$final_rf,type=2,main="Variable Importance Plot")
# Out:
#   feature_name variable_importance module_membership
# 1           V1           50.219580                 2
# 6         V301           27.763997                 0
# 5          V89           25.929765                 2
# 2           V2           20.933159                 2
# 4          V50           17.004763                 2
# 3          V30           13.549684                 2
# 7         V303            5.426569                 0
# 8         V385            1.707946                 0
# plot without title
# Plot with title "Variable Importance Plot"

# %% [markdown]
# # Random Forest

# %% [markdown]
# Test the performance of Random Forest (whether it selectes the correct features) on several data set with different structured on time and features.

# %% [markdown]
# ## Data1

# %%
#data
data1 <- read.csv(file="data1.csv", header=TRUE, sep=",")
data1 = data1[,-1] # delete the X column (name of rows)
X = data1[,-ncol(data1)]
y = data1[,ncol(data1)]

#fit
RF_fit = randomForest(X,y)

#results
varImpPlot(RF_fit,type=2,main="Variable Importance Plot")
# Out:
# Plot with title "Variable Importance Plot"

# %% [markdown]
# ## Data2

# %%
#data
data2 <- read.csv(file="data2.csv", header=TRUE, sep=",")
data2 = data2[,-1] # delete the X column (name of rows)
X = data2[,-ncol(data2)]
y = data2[,ncol(data2)]

#fit
RF_fit = randomForest(X,y)

#results
varImpPlot(RF_fit,type=2,main="Variable Importance Plot")
# Out:
# Plot with title "Variable Importance Plot"

# %% [markdown]
# ## Data3

# %%
#data
data3 <- read.csv(file="data3.csv", header=TRUE, sep=",")
data3 = data3[,-1] # delete the X column (name of rows)
X = data3[,-ncol(data3)]
y = data3[,ncol(data3)]

#fit
RF_fit = randomForest(X,y)

#results
varImpPlot(RF_fit,type=2,main="Variable Importance Plot")
# Out:
# Plot with title "Variable Importance Plot"

# %% [markdown]
# ## Data4

# %%
#data
data4 <- read.csv(file="data4.csv", header=TRUE, sep=",")
data4 = data4[,-1] # delete the X column (name of rows)
X = data4[,-ncol(data4)]
y = data4[,ncol(data4)]

#fit
RF_fit = randomForest(X,y)

#results
varImpPlot(RF_fit,type=2,main="Variable Importance Plot")
# Out:
# Plot with title "Variable Importance Plot"
