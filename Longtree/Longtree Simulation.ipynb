# %% [markdown]
# Test Longtree using different p and p_true

# %%
source("Data Generator.r")
source("Longtree.r")

# %% [markdown]
# Note: the following is where a1=5,a2=-5

# %% [markdown]
# # 1

# %%
### training, validation and test set ###
set.seed(100)
n = 500
p = 400
imp_mod = c(1,4)
var_noise = 1
data = sim_time(n=n,p=p,imp_mod=imp_mod, var_noise=var_noise)
data$time2 = (data$time)^2

# test set (used for testing performance using optimal parameters)
set.seed(101)
n_test = 100
data_test = sim_time(n=n_test,p=p,imp_mod=imp_mod, var_noise=var_noise)
data_test$time2 = (data_test$time)^2

# validation set (used for tuning parameters)
set.seed(102)
n_valid = 100
data_valid = sim_time(n=n_valid,p=p,imp_mod=imp_mod, var_noise=var_noise)
data_valid$time2 = (data_valid$time)^2
###

# %%
# Tuning parameters on the validation set: alpha,maxdepth,Fuzzy
fixed_regress = c("time","time2")
fixed_split = c("treatment")
cluster = "patient"
var_select = paste("V",1:p,sep="")
system.time({
    mytree = Longtree(data,fixed_regress=fixed_regress,fixed_split=fixed_split,
                  var_select=var_select,cluster=cluster,Fuzzy=FALSE,
                     maxdepth_factor_select = 0.8,maxdepth_factor_screen=0.04)
})
mean((predict(mytree,newdata=data_valid,re.form=NA)-data_valid$y)**2)
coef(mytree)
# Out:
# Use Longtree_time
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# After screening within non-grey modules V1 V2 V3 V61
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# The chosen non-grey features are V1 V2 V3
# The chosen grey features are V301 V302 V303
# final features V1 V2 V3 V301 V302 V303
#    user  system elapsed
#   43.64    0.50   44.78
# [1] 10.11661
#    (Intercept) time      time2     V1       V2         V3          V301
# 5   42.53091   -32.42634  5.387650 4.143879 -1.2491410 -4.15937924 4.564612
# 6   40.90258   -30.25900  5.067313 5.106758 -2.9096439 -3.79873813 5.000982
# 9   46.64912   -32.63274  5.433097 5.698366 -2.6858653 -2.49838562 4.444141
# 10  39.25671   -29.58383  4.905652 4.458454 -2.7810146 -3.47382182 4.892068
# 11  43.49166   -31.68048  5.244618 5.787826 -2.6073276 -5.12376100 5.018494
# 14  42.28261   -30.14167  5.010053 5.967379  5.4609973  6.47611512 5.115288
# 17  44.00430   -30.54305  5.082844 5.445095  3.3871558  4.30894914 4.828324
# 18  46.53016   -29.77764  4.943804 4.883186  5.1643678  2.09777056 4.965042
# 19  31.00648   -27.80724  4.675434 3.750078 11.4685446  9.07621772 4.448277
# 22  45.98748   -30.77925  5.127208 4.786018  3.4254385  4.06386551 5.296163
# 23  47.54885   -31.09909  5.204490 3.577220  4.0519468  4.36243411 4.557311
# 24  36.66838   -30.97764  5.153974 3.329926 10.0943405 10.72463575 5.988098
# 29 -52.32180    29.61999 -4.913483 4.909574 -2.5971013 -3.44174082 5.566601
# 30 -48.65408    30.95681 -5.144533 4.818035  1.8792397  0.06714854 4.473462
# 32 -50.11215    30.55047 -5.115783 4.623007 -4.6851674 -4.34420793 5.161325
# 33 -42.75052    29.58138 -4.901774 4.414642  1.8554228  0.40838447 4.716443
# 36 -51.58719    29.93569 -4.979213 5.552726 -4.0051532 -4.94406228 5.425566
# 37 -45.64734    29.80730 -4.944426 4.901432  1.4278231  1.74292745 4.902354
# 38 -45.43396    30.11387 -5.056262 4.718465 -0.6110542 -2.62376007 4.931164
# 41 -55.99205    29.73844 -4.934284 4.898806  7.7955908 10.13066042 4.943800
# 43 -45.97131    30.27087 -5.052244 5.893081  6.5575729  7.27316742 5.445775
# 44 -50.75924    30.33883 -5.053647 5.015261  7.2060131  8.19718257 5.089412
# 45 -52.55448    31.37080 -5.208752 4.874427  8.5992685  9.47227573 5.462160
#    V302       V303
# 5  -5.1592372  0.8319884
# 6  -0.6347582  2.2125085
# 9   3.7956504 -1.3390593
# 10  3.4947833  5.5634307
# 11  8.3746801  1.5258283
# 14  1.4063432 -5.4438035
# 17 -1.9856320  0.6596582
# 18  6.2610873  0.6473990
# 19  2.5400649  0.8817627
# 22  1.1991623  4.8117199
# 23  0.4624950  8.4415290
# 24  0.4983060  6.5548986
# 29 -1.3664832 -2.2775188
# 30 -1.5524992 -2.1043627
# 32 -2.6170123  6.0506796
# 33 -1.1999067  5.1746404
# 36  5.0411845  2.3272712
# 37  4.5909826  3.7102934
# 38 10.0889203  1.7301306
# 41 -2.2304736 -2.0852760
# 43  5.4167100 -3.5793159
# 44  4.2932618  2.2351639
# 45  0.3006564 10.1059774

# %%
# performance of test set
mean((predict(mytree,newdata=data_test,re.form=NA)-data_test$y)**2)
# Out:
# [1] 11.34346

# %% [markdown]
# # 2

# %%
### training, validation and test set ###
set.seed(100)
n = 300
p = 400
imp_mod = c(1,4)
var_noise = 1
data = sim_time(n=n,p=p,imp_mod=imp_mod, var_noise=var_noise)
data$time2 = (data$time)^2

# test set (used for testing performance using optimal parameters)
set.seed(101)
n_test = 100
data_test = sim_time(n=n_test,p=p,imp_mod=imp_mod, var_noise=var_noise)
data_test$time2 = (data_test$time)^2

# validation set (used for tuning parameters)
set.seed(102)
n_valid = 100
data_valid = sim_time(n=n_valid,p=p,imp_mod=imp_mod, var_noise=var_noise)
data_valid$time2 = (data_valid$time)^2
###

# %%
# Tuning parameters on the validation set: alpha,maxdepth,Fuzzy
# here when maxdepth_factor_select is smaller, it will choose more non-grey features!
fixed_regress = c("time","time2")
fixed_split = c("treatment")
cluster = "patient"
var_select = paste("V",1:p,sep="")
system.time({
    mytree = Longtree(data,fixed_regress=fixed_regress,fixed_split=fixed_split,
                  var_select=var_select,cluster=cluster,Fuzzy=FALSE,alpha=0.15,
                     maxdepth_factor_select = 0.8,maxdepth_factor_screen=0.04)
})
mean((predict(mytree,newdata=data_valid,re.form=NA)-data_valid$y)**2)
coef(mytree)
# Out:
# Use Longtree_time
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# After screening within non-grey modules V1 V2 V3 V14 V68 V73 V106 V154 V183
# The chosen non-grey features are V1 V2 V3 V68 V73
# The chosen grey features are V301 V302 V303
# final features V1 V2 V3 V68 V73 V301 V302 V303
#    user  system elapsed
#   29.08    0.37   29.96
# [1] 19.25768
#    (Intercept) time      time2     V1       V2        V3        V68
# 4   42.92367   -31.90288  5.256356 6.796281 -2.970887 -3.799214 -0.70927395
# 5   39.72523   -29.31289  4.859601 4.608790 -3.337653 -3.680966 -0.08965440
# 7   44.55018   -31.01337  5.153488 4.077531  4.566159  7.206680  0.32014345
# 9   49.31146   -30.70090  5.090303 4.583741  5.588418  3.970792  0.02972572
# 10  39.13064   -29.34831  4.907934 4.148213  5.297060  6.395514  0.47635353
# 13 -47.72667    29.82848 -4.937615 4.561987 -2.031927 -2.736983  0.34478305
# 14 -46.39630    31.13696 -5.206227 5.804499 -4.099670 -1.572003 -0.73680410
# 16 -49.51177    30.56845 -5.019570 5.214378  6.660064  6.693891 -0.85860178
# 17 -47.64188    28.61622 -4.693499 5.204670  7.585823  5.658917 -0.10613369
#    V73        V301     V302       V303
# 4  -1.2603726 4.902351 -0.7697256  1.155009
# 5   0.1636778 4.972433  7.1729444  2.074491
# 7   0.4835688 5.064211 -2.3384062  1.284006
# 9   0.2938714 5.077270  6.7292728 -1.455656
# 10  1.1571930 4.800159  5.6042710  6.389439
# 13  0.3161927 5.149373  1.0121402 -1.191477
# 14  0.2380539 5.305400 -0.5170578  6.720108
# 16  1.1439033 5.469443 -1.7203636  2.683671
# 17  0.7294172 5.305078  6.1396624  2.194647

# %%
# performance of test set
mean((predict(mytree,newdata=data_test,re.form=NA)-data_test$y)**2)
# Out:
# [1] 19.75767

# %% [markdown]
# # 3

# %%
### training, validation and test set ###
set.seed(100)
n = 300
p = 1000
imp_mod = c(1,10)
var_noise = 1
data = sim_time(n=n,p=p,imp_mod=imp_mod, var_noise=var_noise)
data$time2 = (data$time)^2

# test set (used for testing performance using optimal parameters)
set.seed(101)
n_test = 100
data_test = sim_time(n=n_test,p=p,imp_mod=imp_mod, var_noise=var_noise)
data_test$time2 = (data_test$time)^2

# validation set (used for tuning parameters)
set.seed(102)
n_valid = 100
data_valid = sim_time(n=n_valid,p=p,imp_mod=imp_mod, var_noise=var_noise)
data_valid$time2 = (data_valid$time)^2
###

# %%
# Tuning parameters on the validation set: alpha,maxdepth,Fuzzy
fixed_regress = c("time","time2")
fixed_split = c("treatment")
cluster = "patient"
var_select = paste("V",1:p,sep="")
system.time({
    mytree = Longtree(data,fixed_regress=fixed_regress,fixed_split=fixed_split,
                  var_select=var_select,cluster=cluster,Fuzzy=TRUE,alpha=0.12,
                     maxdepth_factor_select = 0.8,maxdepth_factor_screen=0.04)
})
mean((predict(mytree,newdata=data_valid,re.form=NA)-data_valid$y)**2)
coef(mytree)
# Out:
# Use Longtree_time
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# after screening within modules V1 V2 V3 V25 V36 V48 V901 V902 V903
# final features V1 V2 V3 V25 V48 V901 V902 V903
#    user  system elapsed
#   29.64    0.78   30.64
# [1] 15.96178
#    (Intercept) time      time2     V1       V2        V3        V25
# 4   41.04723   -28.49301  4.732842 4.186102 -1.303763 -3.950041  1.34615770
# 5   40.41306   -27.13318  4.525691 5.722313 -1.534107 -1.570483  0.33804655
# 8   39.32213   -30.25073  5.076007 5.778410  5.224598  8.468871  0.02175285
# 9   43.37041   -30.28803  4.972303 6.444393  5.414506  8.838913  0.11894928
# 10  40.95962   -30.45604  5.086658 5.351695  5.688490 10.757970 -0.08932167
# 13 -46.45147    28.80955 -4.738537 4.145987 -2.879867 -3.845393  0.02133174
# 14 -47.88495    30.37534 -5.021044 4.677739 -1.083361 -3.825873 -0.94334064
# 16 -48.47459    28.91082 -4.813926 5.945143  6.393102  9.448427  0.75816649
# 17 -51.96115    31.87968 -5.314550 4.570464  7.111157  7.947256  1.41082940
#    V48         V901     V902      V903
# 4  -0.41158381 4.680476 -1.034163  2.0162144
# 5  -0.92885111 4.919259  6.211850  2.1993370
# 8  -0.78472014 5.223856 -2.235898 -1.2884600
# 9  -0.24430104 4.974085  5.471117 -0.9325639
# 10 -0.71076353 4.951075  1.599460  6.3730840
# 13  0.92196347 4.920202 -2.448568  3.6388517
# 14 -0.08917312 5.125529  6.029031  1.0168202
# 16 -0.63373317 4.329167  3.261356 -1.2005648
# 17 -0.01825029 5.302235  1.674831  6.7103225

# %%
# performance of test set
mean((predict(mytree,newdata=data_test,re.form=NA)-data_test$y)**2)
# Out:
# [1] 16.91793

# %% [markdown]
# # 4

# %%
### training, validation and test set ###
set.seed(100)
n = 1500
p = 1000
imp_mod = c(1,2,10)
var_noise = 1
data = sim_time(n=n,p=p,imp_mod=imp_mod, var_noise=var_noise)
data$time2 = (data$time)^2

# test set (used for testing performance using optimal parameters)
set.seed(101)
n_test = 100
data_test = sim_time(n=n_test,p=p,imp_mod=imp_mod, var_noise=var_noise)
data_test$time2 = (data_test$time)^2

# validation set (used for tuning parameters)
set.seed(102)
n_valid = 100
data_valid = sim_time(n=n_valid,p=p,imp_mod=imp_mod, var_noise=var_noise)
data_valid$time2 = (data_valid$time)^2
###

# %%
# Tuning parameters on the validation set: alpha,maxdepth,Fuzzy
fixed_regress = c("time","time2")
fixed_split = c("treatment")
cluster = "patient"
var_select = paste("V",1:p,sep="")
system.time({
    mytree = Longtree(data,fixed_regress=fixed_regress,fixed_split=fixed_split,
                  var_select=var_select,cluster=cluster,Fuzzy=FALSE,alpha=0.2,
                     maxdepth_factor_select = 0.5,maxdepth_factor_screen=0.04)
})
mean((predict(mytree,newdata=data_valid,re.form=NA)-data_valid$y)**2)
coef(mytree)
# Out:
# Use Longtree_time
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# boundary (singular) fit: see ?isSingular
# After screening within non-grey modules V1 V2 V3 V44 V50 V100 V101 V102 V103 V124 V126 V127 V135 V172 V198 V664 V763
# The chosen non-grey features are V1 V2 V3 V44 V100 V101 V102 V103 V126 V127 V135 V172
# The chosen grey features are V901 V986
# final features V1 V2 V3 V44 V100 V101 V102 V103 V126 V127 V135 V172 V901 V986
#    user  system elapsed
#  148.58    5.05  162.18
# [1] 52.38004
#    (Intercept) time      time2     V1       V2         V3         V44
# 5   27.38137   -28.33056  4.799815 3.884230 -6.6103074 -8.0357914  1.2888339
# 7   34.43382   -28.62391  4.696724 5.995702  0.2752485  2.5229438 -0.2357769
# 8   44.18042   -29.82076  5.021583 5.360327  0.3194463 -0.8671401  0.8309398
# 10  38.88342   -30.22032  5.026124 4.133790 -1.6724351 -1.3044903  0.4103844
# 11  29.94527   -28.12188  4.738154 4.454193 -2.0485753 -1.8924508  1.0299258
# 14  31.51798   -29.87494  5.070058 4.821982  7.0862148  7.8620141  1.2091519
# 15  40.94340   -32.48489  5.436162 5.135684  8.3153574 11.3781823 -1.0902639
# 16  33.38692   -28.39427  4.851670 5.294230  5.9432782 10.2947525 -0.6182107
# 19 -56.45669    31.14145 -5.139567 6.160408 -3.4195316 -6.6089101  0.8799322
# 21 -60.78655    32.53330 -5.372150 2.491449 -5.7840085 -3.1051812  0.8027111
# 22 -47.35348    30.20188 -5.014276 4.506555 -0.3070969  2.7001559  0.3626345
# 26 -55.57402    31.37671 -5.197575 7.989812  1.9025648  0.3245663  0.1489450
# 27 -45.44515    31.66728 -5.304358 4.147759  4.4865253  0.3875110  0.1497595
# 28 -60.83543    33.82444 -5.627486 5.677855  8.8903469  9.6638531 -0.1283033
# 31 -47.67541    29.24721 -4.834000 6.463513  1.3045470  4.5376486  1.2122770
# 32 -56.73357    31.69088 -5.201293 5.364760  1.7029446  3.3702914  1.7029506
# 33 -65.34282    32.31760 -5.489598 5.459442  9.1377558 11.9289876 -1.0585086
#    V100       V101     V102       V103       V126       V127       V135
# 5   0.9566966 4.937934 -0.6649841 -3.3604246  0.9784484 -0.2809557 -0.35919656
# 7   0.3156441 3.937781 -4.3223878 -7.7859085  0.6971462 -0.7966107 -0.84588079
# 8  -0.4753102 4.414330  1.3916915  0.3284012  0.5034584  0.6675085 -1.90025364
# 10  0.3872349 5.373830  4.3359837 11.7237154 -0.4141920  0.9138680  1.75712319
# 11 -0.3285281 4.588212  9.3614555  8.4584816  1.1487338  0.5724006 -0.21340970
# 14  1.1084203 3.736204 -4.0127295 -4.9113783  1.9905166  0.2521498  0.01798696
# 15 -1.8887274 4.793496  0.7431321  2.2406956 -0.9022196 -1.2897471 -0.92238761
# 16  0.2931048 4.874295  6.4494115  7.0653563  0.5263411 -0.4757289  0.12326939
# 19 -1.0665127 5.314029 -3.3155583 -1.2963616 -0.5741948  0.6574173 -0.05351041
# 21  0.4315714 4.972747  8.4407011  8.0029804  1.5911570 -1.5921008 -1.08066363
# 22 -0.1017120 4.541734  6.8341049  6.1582668 -0.4529005 -1.4604139  0.23279345
# 26 -0.2015207 4.386494 -3.8201322 -5.5483399 -0.7289429  0.4327419 -0.65361778
# 27  0.1752929 4.625708  1.9053556 -0.0885607  0.2386140 -0.3029943  1.35630230
# 28 -1.5257310 6.098053 -4.6869540 -1.4497861  0.1634575 -1.1507009  0.38696302
# 31 -0.3690416 4.423064 10.3868944  5.3106741 -0.5044892 -1.1592537  0.41950467
# 32  0.1056743 4.453176  9.4670660  7.9323062 -0.5572827 -0.6255048  1.13085941
# 33  0.6603762 4.872763 10.4379077  5.7332173 -0.2039275 -1.2137574 -0.49260840
#    V172       V901     V986
# 5   1.0870932 4.127931 -0.32453977
# 7   2.4129336 6.138480 -0.48152906
# 8   0.1075261 4.649403 -0.11643272
# 10 -2.0522647 5.106106 -0.01041895
# 11  1.2588581 5.169229  0.81895618
# 14  0.9598088 5.429491 -0.01906402
# 15  2.0504778 4.625535  0.03208386
# 16 -0.7384804 3.923871  0.20251153
# 19 -1.7006713 4.203949  0.47291834
# 21 -0.2385191 3.039522  0.17116133
# 22  0.7376291 5.070260  0.91404000
# 26  0.2612123 5.920308 -0.09521056
# 27 -0.3302848 4.887637 -0.06362540
# 28  0.2020192 4.948203  0.45377121
# 31 -0.5144989 4.060855 -0.52792992
# 32  1.0068949 5.688186  0.41190120
# 33  0.7788683 5.149765 -0.25755362

# %%
# performance of test set
mean((predict(mytree,newdata=data_test,re.form=NA)-data_test$y)**2)
# Out:
# [1] 40.17699

# %%
# n=1500
# the final selection among all the chosen features 
var = paste("V",c(1,2,3,101,102,103,901,902,903),sep="")
regress_var = c("time","time2",var)
split_var = c("treatment",var)
Formula = as.formula(paste("y~",paste(regress_var,collapse = "+"),
                   "|",cluster,"|",
                 paste(split_var,collapse = "+")))
system.time({mytree = lmertree(Formula, data = data,alpha = 0.2,maxdepth=10)}) 
mean((predict(mytree,newdata=data_test,re.form=NA)-data_test$y)**2)
coef(mytree)

# %%
# n=300
# the final selection among all the chosen features 
var = paste("V",c(1,2,3,101,102,103,901,902,903),sep="")
regress_var = c("time","time2",var)
split_var = c("treatment",var)
Formula = as.formula(paste("y~",paste(regress_var,collapse = "+"),
                   "|",cluster,"|",
                 paste(split_var,collapse = "+")))
system.time({mytree = lmertree(Formula, data = data,alpha = 0.2,maxdepth=10)}) 
mean((predict(mytree,newdata=data_test,re.form=NA)-data_test$y)**2)
coef(mytree)
# Out:
#    user  system elapsed
#    1.90    0.04    2.03
# [1] 56.06573
#    (Intercept) time      time2     V1       V2        V3        V101
# 4   44.90980   -29.57616  4.968976 4.640319 3.2832787  3.012703 4.560346
# 5   42.66365   -26.94165  4.517655 3.404279 0.6932297  4.444411 5.817528
# 7   44.86620   -29.75641  4.909501 5.789024 2.7804828  3.659190 5.464242
# 8   46.33473   -30.02033  4.993673 3.862002 4.6682410  2.446125 4.534118
# 11 -54.28176    31.79917 -5.226427 5.891653 1.3442317 -5.502431 5.458785
# 12 -59.52117    33.17711 -5.540251 5.357073 8.8565739  9.581937 5.041620
# 14 -43.04349    28.74801 -4.616610 6.078445 1.0455432  2.052743 3.977878
# 15 -42.01779    28.13775 -4.680428 5.064422 1.6277103  2.835324 2.168716
#    V102       V103       V901     V902      V903
# 4  -0.9672506 -3.3625355 4.862630  2.099138 -1.593515
# 5  -0.5968983 -4.0811116 4.369750  3.033392  5.909296
# 7   4.4407280  9.7272006 5.157877  1.894878 -1.546823
# 8   7.7659023  5.2772325 5.324488  3.107707  7.286150
# 11 -5.9198998 -1.8170243 4.504876  1.526616  1.008786
# 12 -4.5992256 -0.8143977 4.620882  1.555821  3.323359
# 14  7.6938791  8.3707524 6.146541 -3.456235  3.633714
# 15  8.6984464  7.9426178 5.036639  5.450216  2.884678

# %% [markdown]
# # Something is wrong in my simulation function!
