# %%
library(REEMtree)
source("SimData.r")
# Out:
# Warning message:
# "package 'REEMtree' was built under R version 3.6.1"Loading required package: nlme
# Loading required package: rpart

# %%
# simulate the data
n = 100
T = 5
set.seed(100)
data = sim_3(n,T)
data = data.frame(data)

# features name are V1,...,V400 
names(data) = c(paste("V",1:400,sep=""),"y")

# add patient/cluster information
for (i in 1:n){
    data$ID[(1+(i-1)*T):(i*T)] = rep(i,T)
}

# see the data
head(data)
# Out:
#   V1         V2         V3         V4         V5         V6          V7
# 1  0.4041948 -0.1157621 -0.8282505 -0.2551767  0.7114005  0.09327738  0.4703178
# 2 -0.5048507 -1.1607588 -0.9535845 -1.1433429 -0.3331617 -1.11665992 -0.4615737
# 3 -0.8002010 -0.8082677 -1.0642596 -1.0390025 -0.5794711 -0.98738083 -0.5376431
# 4 -0.9136394 -1.3453939 -1.2412924 -0.5843280 -0.7852858 -1.10955238 -1.0380377
# 5 -1.1862461 -0.8985310 -1.1362628 -0.5670641 -0.4920586 -0.39728046 -0.6302260
# 6  0.7559472  2.1693698  1.1034058  1.9401066  0.6839483  1.12735727  1.5714702
#   V8         V9          V10        ... V393        V394        V395
# 1 -0.5625359  0.71595493  0.1898496 ...  0.08988614 -0.35986213 -0.8252594
# 2 -1.5207829  0.02850286 -0.3527653 ...  0.72234331  0.07727177 -0.1601616
# 3 -1.4163408 -0.22285559 -0.4874867 ...  0.30580294 -0.30489980 -1.1099505
# 4 -1.3915048 -0.74088698 -0.3579343 ... -0.05012705  0.09587574 -0.7253685
# 5 -0.6027598 -0.23438185 -0.3974606 ... -0.71418211  0.15796748  0.4595740
# 6  1.5045449  1.51050327  1.6902715 ...  1.29711493  0.14826603 -1.0999877
#   V396        V397       V398        V399       V400        y          ID
# 1  0.71453271 -0.5817907  0.31863009  0.1169713  0.88678481  -2.680183 1
# 2 -0.05631991 -1.6737887  0.91176834 -0.5207258  0.08539332 -11.353485 1
# 3 -0.22036390 -2.4876058  0.85579524  0.1344519 -0.31106741  -9.402297 1
# 4 -0.07577874 -3.0802759  0.76572763 -0.3152833  0.01155116  -2.714342 1
# 5  0.87427111 -2.9496439  0.05246792 -0.7299419 -0.76754000  -8.588217 1
# 6 -0.55237209  0.2431390 -1.33757722 -0.2405078 -0.62730903  20.835334 2

# %%
# we use all the features here
variables = paste("V",1:400,sep="")
# formula
Formular = as.formula(paste("y~",paste(variables,collapse = "+")))
# Formular

# %%
system.time({REEMresult<-REEMtree(Formular, data=data, random=~1|ID)})
plot(REEMresult)
# Out:
#    user  system elapsed
#    1.10    0.00    1.12
# plot without title

# %%
# The first way to get important features, which does not match the plot of tree
sort(REEMresult$Tree$variable.importance, decreasing = TRUE)
# Out:
#        V84        V36        V83        V25        V61         V8         V1
# 33127.9248 17155.5325 17155.5325 16563.9624 16563.9624 16563.9624  7816.5816
#       V301        V15         V3        V21        V13        V10         V7
#  7154.1098  5977.0106  5033.2721  4404.1130  4357.2031  4089.5335  4089.5335
#        V23        V49        V56        V39        V92        V45       V187
#  3643.8200  3585.0487  3585.0487  3526.2774  3526.2774  1295.3392  1272.7216
#       V125       V140       V176       V184       V113       V379       V168
#  1048.1237  1048.1237  1048.1237  1048.1237   973.2577   773.2398   756.2703
#        V35        V42        V46        V62        V19       V132       V278
#   631.8728   631.8728   600.2791   600.2791   568.6855   446.0999   446.0999
#       V368       V229       V382       V392        V74       V102       V127
#   446.0999   312.2811   312.2811   312.2811   312.2811   220.9504   220.9504
#       V151       V169
#   220.9504   220.9504

# %%
# Another way: extract the features used in the node:
(REEMresult$Tree$frame$var)
# Out:
#  [1] V84    V1     V301   <leaf> V301   <leaf> <leaf> V301   <leaf> V45
# [11] <leaf> <leaf> V15    V187   <leaf> <leaf> <leaf>
# 32 Levels: <leaf> V1 V133 V141 V15 V187 V188 V199 V2 V21 V26 V264 V288 ... V89
